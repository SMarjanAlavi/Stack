# %% [markdown]
#  What are the most frequently used Computer Skills in Toronto?
# ## (Based on StackOverflow posts in Q2 2018.)

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import datetime

# Read the data from the result of the query file
# Downloaded from "http://data.stackexchange.com/stackoverflow/query/edit/878134"
# at 2:50 pm on 2 Aug 2018.

df=pd.read_csv("python2018Q2.csv", sep=',')

#print (df.head())
locations = set(df['Location'].tolist())
#print(locations)
df_Date_Location_TagName = df.loc[:,['Location', 'TagName']]
print('We are investigating', len(df1), 'posts between', min(df1['Date']),'to', max(df1['Date']),\
      'from', len(locations), 'locations.\n')
# Out:
# We are investigating 43630 posts between 2018-04-01 00:00:29 to 2018-06-30 23:50:03 from 3205 locations.

# %% [markdown]
# # In which city was Python used more frequently during May to July 2018?

# %%
#print (df_Date_Location_TagName)
df_Location_group = df_Date_Location_TagName.groupby(['Location']).agg({'count'}).sort_values(('TagName', 'count'), ascending=False)
#print(df_Location_group)
df4 = df_Location_group.head(20)
print(df4)
Top_Locations = df4.index.tolist()
#print(Top_Locations)
# Out:
#                                TagName
#                                  count
# Location
# London, UK                        1197
# Seattle, WA                        810
# United Kingdom                     712
# on the server farm                 659
# Peru                               640
# Shanghai, China                    573
# India                              566
# Los Angeles, CA, United States     549
# London, United Kingdom             548
# Germany                            486
# Austria                            465
# United States                      347
# Paris, France                      277
# Bangalore, Karnataka, India        271
# Cambridge, United Kingdom          266
# Mountain View, CA                  263
# Munich, Germany                    259
# Pune, Maharashtra, India           252
# France                             219
# West Mids, UK                      213

# %%
print('Top locations: ', Top_Locations)

print('\nAs it can be seen from the chart,', df4[('TagName','count')].idxmax(), 'is the top location most for Python.\n')

fig = df4.plot.bar(title = print('Top python cities \n between', min(df1['Date']), 'to',  max(df1['Date'])));
fig.legend_.remove();
fig.set_xlabel("Location");
fig.set_ylabel("Number of releavant Tags\n in the StackOverflow posts");
# Out:
# Top locations:  ['London, UK', 'Seattle, WA', 'United Kingdom', 'on the server farm', 'Peru', 'Shanghai, China', 'India', 'Los Angeles, CA, United States', 'London, United Kingdom', 'Germany', 'Austria', 'United States', 'Paris, France', 'Bangalore, Karnataka, India', 'Cambridge, United Kingdom', 'Mountain View, CA', 'Munich, Germany', 'Pune, Maharashtra, India', 'France', 'West Mids, UK']
#
# As it can be seen from the chart, London, UK is the top location most for Python.
#
# Top python cities
#  between 2018-04-01 00:00:29 to 2018-06-30 23:50:03
